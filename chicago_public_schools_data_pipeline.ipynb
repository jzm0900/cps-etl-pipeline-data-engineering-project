# %%
import pandas as pd
import requests

# %%
csv = 'CPS_Data_with_Lat_Long.csv'

df = pd.read_csv(csv)

# %%
df.head(3)
# Out:
#    School_ID    Short_Name                        Long_Name   School_Type  \
# 0     610125          RUIZ    Irma C Ruiz Elementary School  Neighborhood
# 1     609728  ROOSEVELT HS   Theodore Roosevelt High School  Neighborhood
# 2     610040         LLOYD  Henry D Lloyd Elementary School  Neighborhood
#
#   Primary_Category            Address     City     State    Zip         Phone  \
# 0               ES  2410 S LEAVITT ST  Chicago  Illinois  60608  773-535-4825
# 1               HS  3436 W WILSON AVE  Chicago  Illinois  60625  773-534-5000
# 2               ES   2103 N LAMON AVE  Chicago  Illinois  60639  773-534-3070
#
#    ... Attainment_All_Grades_School_Pct Attainment_All_Grades_School_Lbl  \
# 0  ...                              0.0                              0.0
# 1  ...                             17.1                             17.1
# 2  ...                              0.0                              0.0
#
#   Growth_PSAT_Math_Grade_10_School_Pct  Growth_PSAT_Math_Grade_10_School_Lbl  \
# 0                                  NaN                                   NaN
# 1                                  NaN                                   NaN
# 2                                  NaN                                   NaN
#
#    Growth_SAT_Reading_Grade_11_School_Pct  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
#
#    Growth_SAT_Reading_Grade_11_School_Lbl  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
#
#    Growth_SAT_Math_Grade_11_School_Pct  Growth_SAT_Math_Grade_11_School_Lbl  \
# 0                                  NaN                                  NaN
# 1                                  NaN                                  NaN
# 2                                  NaN                                  NaN
#
#     latitude  longitude
# 0  41.847773 -87.681381
# 1  41.965766 -87.714183
# 2  41.919018 -87.748268
#
# [3 rows x 184 columns]

# %%
# convert the values in the columns to int
df['Other_Metrics_Year_1'] = pd.to_numeric(df['Other_Metrics_Year_1'], errors='coerce').astype('Int64')

df['Other_Metrics_Year_2'] = pd.to_numeric(df['Other_Metrics_Year_2'], errors='coerce').astype('Int64')

df['Other_Metrics_Year_2']
# Out:
# 0      2022
# 1      2022
# 2      2022
# 3      2022
# 4      2022
#        ...
# 645    2022
# 646    2022
# 647    2022
# 648    2022
# 649    2022
# Name: Other_Metrics_Year_2, Length: 650, dtype: Int64

# %%
# using Google Maps API to get the longitude and latitude and assign them to new columns in the dataframe

# Your Google Maps Geocoding API key
google_api_key = 'AIzaSyB31hqCoMO8cWqL9rLtq5Z562Hvq1WXuj8'

# Function to get latitude and longitude from address using Google Maps Geocoding API
def get_lat_long_google_maps(address, api_key):
    base_url = "https://maps.googleapis.com/maps/api/geocode/json"
    params = {
        'address': address,
        'key': api_key,
    }

    response = requests.get(base_url, params=params)
    result = response.json()

    if result['status'] == 'OK':
        location = result['results'][0]['geometry']['location']
        return location['lat'], location['lng']
    else:
        return None, None

# Apply the function to create new 'latitude' and 'longitude' columns
#df['latitude'], df['longitude'] = zip(*df['Address'].apply(get_lat_long_google_maps, api_key=google_api_key))

# Display the updated DataFrame

# %%
df.head(20)
# Out:
#     School_ID       Short_Name                                      Long_Name  \
# 0      610125             RUIZ                  Irma C Ruiz Elementary School
# 1      609728     ROOSEVELT HS                 Theodore Roosevelt High School
# 2      610040            LLOYD                Henry D Lloyd Elementary School
# 3      609983           HEDGES                 James Hedges Elementary School
# 4      610225         WHISTLER                John Whistler Elementary School
# 5      610016          KELLOGG               Kate S Kellogg Elementary School
# 6      610081         SHERIDAN           Mark Sheridan Math & Science Academy
# 7      610073         MITCHELL               Ellen Mitchell Elementary School
# 8      609839          CARROLL  Carroll-Rosenwald Specialty Elementary School
# 9      400112     ACERO - IDAR            Acero Charter Schools - Jovita Idar
# 10     610380      WILLIAMS HS   Daniel Hale Williams Prep School of Medicine
# 11     610130            PIRIE    John T Pirie Fine Arts & Academic Center ES
# 12     610212      ALBANY PARK              Albany Park Multicultural Academy
# 13     609704      FARRAGUT HS    David G Farragut Career Academy High School
# 14     610022           KILMER                 Joyce Kilmer Elementary School
# 15     609918            FIELD                 Eugene Field Elementary School
# 16     609954          GREGORY          John Milton Gregory Elementary School
# 17     610082  MOUNT GREENWOOD              Mount Greenwood Elementary School
# 18     609959           HAINES          John Charles Haines Elementary School
# 19     610279           TANNER               Henry O Tanner Elementary School
#
#      School_Type Primary_Category                Address     City     State  \
# 0   Neighborhood               ES      2410 S LEAVITT ST  Chicago  Illinois
# 1   Neighborhood               HS      3436 W WILSON AVE  Chicago  Illinois
# 2   Neighborhood               ES       2103 N LAMON AVE  Chicago  Illinois
# 3   Neighborhood               ES  4747 S WINCHESTER AVE  Chicago  Illinois
# 4   Neighborhood               ES         11533 S ADA ST  Chicago  Illinois
# 5   Neighborhood               ES      9241 S LEAVITT ST  Chicago  Illinois
# 6         Magnet               ES          533 W 27TH ST  Chicago  Illinois
# 7   Neighborhood               ES         2233 W OHIO ST  Chicago  Illinois
# 8   Neighborhood               ES         2929 W 83RD ST  Chicago  Illinois
# 9        Charter               ES       5050 S HOMAN AVE  Chicago  Illinois
# 10         Small               HS      4934 S WABASH AVE  Chicago  Illinois
# 11  Neighborhood               ES          650 E 85TH ST  Chicago  Illinois
# 12  Neighborhood               MS      4929 N SAWYER AVE  Chicago  Illinois
# 13  Neighborhood               HS  2345 S CHRISTIANA AVE  Chicago  Illinois
# 14  Neighborhood               ES   6700 N GREENVIEW AVE  Chicago  Illinois
# 15  Neighborhood               ES     7019 N ASHLAND AVE  Chicago  Illinois
# 16  Neighborhood               ES         3715 W POLK ST  Chicago  Illinois
# 17  Neighborhood               ES      10841 S HOMAN AVE  Chicago  Illinois
# 18  Neighborhood               ES          247 W 23RD PL  Chicago  Illinois
# 19  Neighborhood               ES       7350 S EVANS AVE  Chicago  Illinois
#
#       Zip         Phone  ... Attainment_All_Grades_School_Pct  \
# 0   60608  773-535-4825  ...                              0.0
# 1   60625  773-534-5000  ...                             17.1
# 2   60639  773-534-3070  ...                              0.0
# 3   60609  773-535-7360  ...                              0.0
# 4   60643  773-535-5560  ...                              0.0
# 5   60643  773-535-2590  ...                              0.0
# 6   60616  773-534-9120  ...                              0.0
# 7   60612  773-534-7655  ...                              0.0
# 8   60652  773-535-9414  ...                              0.0
# 9   60632  312-455-5450  ...                              0.0
# 10  60615  773-535-1120  ...                              2.6
# 11  60619  773-535-3435  ...                              0.0
# 12  60625  773-534-5108  ...                              0.0
# 13  60623  773-534-1300  ...                             13.1
# 14  60626  773-534-2115  ...                              0.0
# 15  60626  773-534-2030  ...                              0.0
# 16  60624  773-534-6820  ...                              0.0
# 17  60655  773-535-2786  ...                              0.0
# 18  60616  773-534-9200  ...                              0.0
# 19  60619  773-535-3870  ...                              0.0
#
#    Attainment_All_Grades_School_Lbl Growth_PSAT_Math_Grade_10_School_Pct  \
# 0                               0.0                                  NaN
# 1                              17.1                                  NaN
# 2                               0.0                                  NaN
# 3                               0.0                                  NaN
# 4                               0.0                                  NaN
# 5                               0.0                                  NaN
# 6                               0.0                                  NaN
# 7                               0.0                                  NaN
# 8                               0.0                                  NaN
# 9                               0.0                                  NaN
# 10                              2.6                                  NaN
# 11                              0.0                                  NaN
# 12                              0.0                                  NaN
# 13                             13.1                                  NaN
# 14                              0.0                                  NaN
# 15                              0.0                                  NaN
# 16                              0.0                                  NaN
# 17                              0.0                                  NaN
# 18                              0.0                                  NaN
# 19                              0.0                                  NaN
#
#     Growth_PSAT_Math_Grade_10_School_Lbl  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# 5                                    NaN
# 6                                    NaN
# 7                                    NaN
# 8                                    NaN
# 9                                    NaN
# 10                                   NaN
# 11                                   NaN
# 12                                   NaN
# 13                                   NaN
# 14                                   NaN
# 15                                   NaN
# 16                                   NaN
# 17                                   NaN
# 18                                   NaN
# 19                                   NaN
#
#     Growth_SAT_Reading_Grade_11_School_Pct  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# 5                                      NaN
# 6                                      NaN
# 7                                      NaN
# 8                                      NaN
# 9                                      NaN
# 10                                     NaN
# 11                                     NaN
# 12                                     NaN
# 13                                     NaN
# 14                                     NaN
# 15                                     NaN
# 16                                     NaN
# 17                                     NaN
# 18                                     NaN
# 19                                     NaN
#
#     Growth_SAT_Reading_Grade_11_School_Lbl  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# 5                                      NaN
# 6                                      NaN
# 7                                      NaN
# 8                                      NaN
# 9                                      NaN
# 10                                     NaN
# 11                                     NaN
# 12                                     NaN
# 13                                     NaN
# 14                                     NaN
# 15                                     NaN
# 16                                     NaN
# 17                                     NaN
# 18                                     NaN
# 19                                     NaN
#
#     Growth_SAT_Math_Grade_11_School_Pct  Growth_SAT_Math_Grade_11_School_Lbl  \
# 0                                   NaN                                  NaN
# 1                                   NaN                                  NaN
# 2                                   NaN                                  NaN
# 3                                   NaN                                  NaN
# 4                                   NaN                                  NaN
# 5                                   NaN                                  NaN
# 6                                   NaN                                  NaN
# 7                                   NaN                                  NaN
# 8                                   NaN                                  NaN
# 9                                   NaN                                  NaN
# 10                                  NaN                                  NaN
# 11                                  NaN                                  NaN
# 12                                  NaN                                  NaN
# 13                                  NaN                                  NaN
# 14                                  NaN                                  NaN
# 15                                  NaN                                  NaN
# 16                                  NaN                                  NaN
# 17                                  NaN                                  NaN
# 18                                  NaN                                  NaN
# 19                                  NaN                                  NaN
#
#      latitude  longitude
# 0   41.847773 -87.681381
# 1   41.965766 -87.714183
# 2   41.919018 -87.748268
# 3   41.807295 -87.673114
# 4   41.684160 -87.654954
# 5   41.725195 -87.676846
# 6   40.751069 -74.003799
# 7   41.891904 -87.683423
# 8   41.742116 -87.696900
# 9   41.801106 -87.709603
# 10  41.804651 -87.625509
# 11  40.639754 -73.912043
# 12  41.971085 -87.709423
# 13  41.849550 -87.708178
# 14  42.004164 -87.668422
# 15  42.009743 -87.669570
# 16  41.870475 -87.718622
# 17  41.738782 -87.706950
# 18  30.190756 -85.664452
# 19  41.760764 -87.606989
#
# [20 rows x 184 columns]

# %%
df.info()

# %%
df.index.name = 'Index'

# %%
df.head(4)
# Out:
#        School_ID    Short_Name                        Long_Name   School_Type  \
# Index
# 0         610125          RUIZ    Irma C Ruiz Elementary School  Neighborhood
# 1         609728  ROOSEVELT HS   Theodore Roosevelt High School  Neighborhood
# 2         610040         LLOYD  Henry D Lloyd Elementary School  Neighborhood
# 3         609983        HEDGES   James Hedges Elementary School  Neighborhood
#
#       Primary_Category                Address     City     State    Zip  \
# Index
# 0                   ES      2410 S LEAVITT ST  Chicago  Illinois  60608
# 1                   HS      3436 W WILSON AVE  Chicago  Illinois  60625
# 2                   ES       2103 N LAMON AVE  Chicago  Illinois  60639
# 3                   ES  4747 S WINCHESTER AVE  Chicago  Illinois  60609
#
#               Phone  ... Attainment_All_Grades_School_Pct  \
# Index                ...
# 0      773-535-4825  ...                              0.0
# 1      773-534-5000  ...                             17.1
# 2      773-534-3070  ...                              0.0
# 3      773-535-7360  ...                              0.0
#
#       Attainment_All_Grades_School_Lbl Growth_PSAT_Math_Grade_10_School_Pct  \
# Index
# 0                                  0.0                                  NaN
# 1                                 17.1                                  NaN
# 2                                  0.0                                  NaN
# 3                                  0.0                                  NaN
#
#        Growth_PSAT_Math_Grade_10_School_Lbl  \
# Index
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
#
#        Growth_SAT_Reading_Grade_11_School_Pct  \
# Index
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
#
#        Growth_SAT_Reading_Grade_11_School_Lbl  \
# Index
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
#
#        Growth_SAT_Math_Grade_11_School_Pct  \
# Index
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
#
#        Growth_SAT_Math_Grade_11_School_Lbl   latitude  longitude
# Index
# 0                                      NaN  41.847773 -87.681381
# 1                                      NaN  41.965766 -87.714183
# 2                                      NaN  41.919018 -87.748268
# 3                                      NaN  41.807295 -87.673114
#
# [4 rows x 184 columns]

# %%
culture_climate_dim = df[['Culture_Climate_Rating', 'Culture_Climate_Description']].copy()
culture_climate_dim['School_ID'] = df['School_ID'].values
culture_climate_dim
# Out:
#       Culture_Climate_Rating  \
# Index
# 0                  ORGANIZED
# 1             WELL ORGANIZED
# 2                  ORGANIZED
# 3          NOT YET ORGANIZED
# 4            NOT ENOUGH DATA
# ...                      ...
# 645                ORGANIZED
# 646           WELL ORGANIZED
# 647      PARTIALLY ORGANIZED
# 648      PARTIALLY ORGANIZED
# 649           WELL ORGANIZED
#
#                              Culture_Climate_Description  School_ID
# Index
# 0      Results are based on student and teacher respo...     610125
# 1      Results are based on student and teacher respo...     609728
# 2      Results are based on student and teacher respo...     610040
# 3      Results are based on student and teacher respo...     609983
# 4      Results are based on student and teacher respo...     610225
# ...                                                  ...        ...
# 645    Results are based on student and teacher respo...     610563
# 646    Results are based on student and teacher respo...     610570
# 647    Results are based on student and teacher respo...     609764
# 648    Results are based on student and teacher respo...     610106
# 649    Results are based on student and teacher respo...     609726
#
# [650 rows x 3 columns]

# %%
# Create the school_dim and location_dim DataFrame etc...
school_dim = df[['Short_Name', 'Long_Name', 'School_Type', 'Primary_Category', 'Fax', 'CPS_School_Profile', 'Website']].copy()
school_dim['School_ID'] = df['School_ID'].values
school_dim

location_dim = df[['longitude', 'latitude', 'Address', 'City', 'State', 'Zip']].copy()
location_dim['School_ID'] = df['School_ID'].values
location_dim

awards_recognition_dim = df[['Blue_Ribbon_Award_Year', 
                             'Excelerate_Award_Gold_Year', 
                             'Spot_Light_Award_Year', 
                             'Improvement_Award_Year', 
                             'Excellence_Award_Year',
                             'Supportive_School_Award',
                             'Supportive_School_Award_Desc',
                             'Progress_Report_Year']].copy()
awards_recognition_dim['School_ID'] = df['School_ID'].values
awards_recognition_dim

culture_climate_dim = df[['Culture_Climate_Rating', 'Culture_Climate_Description']].copy()
culture_climate_dim['School_ID'] = df['School_ID'].values
culture_climate_dim

school_survey_dim = df[['School_Survey_Rating_Description', 
                        'School_Survey_Student_Response_Rate_Pct', 
                        'School_Survey_Student_Response_Rate_Avg_Pct', 
                        'School_Survey_Teacher_Response_Rate_Pct',
                        'School_Survey_Teacher_Response_Rate_Avg_Pct', 
                        'School_Survey_Parent_Response_Rate_Pct',
                        'School_Survey_Parent_Response_Rate_Avg_Pct',
                        'School_Survey_Involved_Families',
                        'School_Survey_Supportive_Environment',
                        'School_Survey_Ambitious_Instruction',
                        'School_Survey_Effective_Leaders',
                        'School_Survey_Collaborative_Teachers', 
                        'School_Survey_Safety',
                        'Parent_Survey_Results_Year']].copy()
school_survey_dim['School_ID'] = df['School_ID'].values
school_survey_dim

attendance_dim = df[['Student_Attendance_Year_1_Pct', 
                     'Student_Attendance_Year_2_Pct', 
                     'Student_Attendance_Avg_Pct',
                     'Teacher_Attendance_Year_1_Pct',
                     'Teacher_Attendance_Year_2_Pct',
                     'Teacher_Attendance_Avg_Pct']].copy()
attendance_dim['School_ID'] = df['School_ID'].values
attendance_dim

creative_school_certification_dim = df[['Creative_School_Certification', 'Creative_School_Certification_Description']].copy()
creative_school_certification_dim['School_ID'] = df['School_ID'].values
creative_school_certification_dim

healthy_school_certification_dim = df[['Healthy_School_Certification', 'Healthy_School_Certification_Description']].copy()
healthy_school_certification_dim['School_ID'] = df['School_ID'].values
healthy_school_certification_dim

attainment_all_grades_school_lbl_dim = df[['Attainment_All_Grades_School_Pct', 'Attainment_All_Grades_School_Lbl']].copy()
attainment_all_grades_school_lbl_dim['School_ID'] = df['School_ID'].values
attainment_all_grades_school_lbl_dim

student_attainment_dim = df[['Student_Attainment_Rating', 'Student_Attainment_Description', 'Attainment_Reading_Pct_ES',
                             'Attainment_Reading_Lbl_ES', 'Attainment_Math_Pct_ES', 'Attainment_Math_Lbl_ES']].copy()
student_attainment_dim['School_ID'] = df['School_ID'].values
student_attainment_dim

attainment_all_grades_school_lbl_dim = df[['Attainment_All_Grades_School_Pct', 'Attainment_All_Grades_School_Lbl']].copy()
attainment_all_grades_school_lbl_dim['School_ID'] = df['School_ID'].values
attainment_all_grades_school_lbl_dim

suspension_and_discipline_dim = df[['Suspensions_Per_100_Students_Year_1_Pct', 'Suspensions_Per_100_Students_Year_2_Pct',
                                    'Suspensions_Per_100_Students_Avg_Pct', 'Misconducts_To_Suspensions_Year_1_Pct', 'Misconducts_To_Suspensions_Year_2_Pct',
                                    'Misconducts_To_Suspensions_Avg_Pct', 'Average_Length_Suspension_Year_1_Pct', 'Average_Length_Suspension_Year_2_Pct',
                                    'Average_Length_Suspension_Avg_Pct', 'Behavior_Discipline_Year_1', 'Behavior_Discipline_Year_2' ]].copy()
suspension_and_discipline_dim['School_ID'] = df['School_ID'].values
suspension_and_discipline_dim

attainment_psat_grade_9_school_dim = df[['Attainment_PSAT_Grade_9_School_Pct', 'Attainment_PSAT_Grade_9_School_Lbl']].copy()
attainment_psat_grade_9_school_dim['School_ID'] = df['School_ID'].values
attainment_psat_grade_9_school_dim

attainment_psat_grade_10_school_dim = df[['Attainment_PSAT_Grade_10_School_Pct', 'Attainment_PSAT_Grade_10_School_Lbl']].copy()
attainment_psat_grade_10_school_dim['School_ID'] = df['School_ID'].values
attainment_psat_grade_10_school_dim

attainment_sat_grade_11_school_dim = df[['Attainment_SAT_Grade_11_School_Pct', 'Attainment_SAT_Grade_11_School_Lbl']].copy()
attainment_sat_grade_11_school_dim['School_ID'] = df['School_ID'].values
attainment_sat_grade_11_school_dim

graduation_4_year_school_dim = df[['Graduation_4_Year_School_Pct_Year_2', 'Graduation_4_Year_CPS_Pct_Year_2', 'Graduation_4_Year_School_Pct_Year_1',
                                   'Graduation_4_Year_CPS_Pct_Year_1']].copy()
graduation_4_year_school_dim['School_ID'] = df['School_ID'].values
graduation_4_year_school_dim


graduation_5_year_school_dim = df[['Graduation_5_Year_School_Pct_Year_2', 'Graduation_5_Year_CPS_Pct_Year_2', 'Graduation_5_Year_School_Pct_Year_1',
                                   'Graduation_5_Year_CPS_Pct_Year_1']].copy()
graduation_5_year_school_dim['School_ID'] = df['School_ID'].values
graduation_5_year_school_dim

sat_grade_11_dim = df[['SAT_Grade_11_Score_School_Avg', 'SAT_Grade_11_Score_CPS_Avg']].copy()
sat_grade_11_dim['School_ID'] = df['School_ID'].values
sat_grade_11_dim

college_enrollment_dim = df[['College_Enrollment_School_Pct_Year_2', 'College_Enrollment_CPS_Pct_Year_2',
                             'College_Enrollment_School_Pct_Year_1', 'College_Enrollment_CPS_Pct_Year_1',
                             'College_Persistence_School_Pct_Year_2', 'College_Persistence_CPS_Pct_Year_2',
                             'College_Persistence_School_Pct_Year_1', 'College_Persistence_CPS_Pct_Year_1', 'Progress_Toward_Graduation_Year_1',
                             'Progress_Toward_Graduation_Year_2']].copy()
college_enrollment_dim['School_ID'] = df['School_ID'].values
college_enrollment_dim

freshmen_on_track_school_dim = df[['Freshmen_On_Track_School_Pct_Year_2', 'Freshmen_On_Track_CPS_Pct_Year_2',
                                   'Freshmen_On_Track_School_Pct_Year_1', 'Freshmen_On_Track_CPS_Pct_Year_1']].copy()
freshmen_on_track_school_dim['School_ID'] = df['School_ID'].values
freshmen_on_track_school_dim

dropout_dim = df[['One_Year_Dropout_Rate_Year_1_Pct', 'One_Year_Dropout_Rate_Year_2_Pct', 'One_Year_Dropout_Rate_Avg_Pct']].copy()
dropout_dim['School_ID'] = df['School_ID'].values
dropout_dim
# Out:
#        One_Year_Dropout_Rate_Year_1_Pct  One_Year_Dropout_Rate_Year_2_Pct  \
# Index
# 0                                   NaN                               NaN
# 1                                   2.1                               4.6
# 2                                   NaN                               NaN
# 3                                   NaN                               NaN
# 4                                   NaN                               NaN
# ...                                 ...                               ...
# 645                                 0.1                               1.0
# 646                                20.9                              36.6
# 647                                 2.1                               2.8
# 648                                 NaN                               NaN
# 649                                 1.1                               1.7
#
#        One_Year_Dropout_Rate_Avg_Pct  School_ID
# Index
# 0                                NaN     610125
# 1                                6.1     609728
# 2                                NaN     610040
# 3                                NaN     609983
# 4                                NaN     610225
# ...                              ...        ...
# 645                              6.1     610563
# 646                              6.1     610570
# 647                              6.1     609764
# 648                              NaN     610106
# 649                              6.1     609726
#
# [650 rows x 4 columns]

# %%
# create the fact table

school_fact_table = df.merge(school_dim, on='School_ID', how='left')\
                    .merge(location_dim, on='School_ID', how='left')\
                    .merge(awards_recognition_dim, on='School_ID', how='left')\
                    .merge(culture_climate_dim, on='School_ID', how='left')\
                    .merge(school_survey_dim, on='School_ID', how='left')\
                    .merge(attendance_dim, on='School_ID', how='left')\
                    .merge(creative_school_certification_dim, on='School_ID', how='left')\
                    .merge(healthy_school_certification_dim, on='School_ID', how='left')\
                    .merge(attainment_all_grades_school_lbl_dim, on='School_ID', how='left')\
                    .merge(student_attainment_dim, on='School_ID', how='left')\
                    .merge(suspension_and_discipline_dim, on='School_ID', how='left')\
                    .merge(attainment_psat_grade_9_school_dim, on='School_ID', how='left')\
                    .merge(attainment_psat_grade_10_school_dim, on='School_ID', how='left')\
                    .merge(attainment_sat_grade_11_school_dim, on='School_ID', how='left')\
                    .merge(graduation_4_year_school_dim, on='School_ID', how='left')\
                    .merge(graduation_5_year_school_dim, on='School_ID', how='left')\
                    .merge(sat_grade_11_dim, on='School_ID', how='left')\
                    .merge(college_enrollment_dim, on='School_ID', how='left')\
                    .merge(freshmen_on_track_school_dim, on='School_ID', how='left')\
                    .merge(dropout_dim, on='School_ID', how='left')\
                    [['School_ID', 'State_School_Report_Card_URL', 'Mobility_Rate_Pct', 'Chronic_Truancy_Pct',
                      'Other_Metrics_Year_1', 'Other_Metrics_Year_2']].copy()
school_fact_table
# Out:
#      School_ID                       State_School_Report_Card_URL  \
# 0       610125  http://iirc.niu.edu/School.aspx?schoolid=15016...
# 1       609728  http://iirc.niu.edu/School.aspx?schoolid=15016...
# 2       610040  http://iirc.niu.edu/School.aspx?schoolid=15016...
# 3       609983  http://iirc.niu.edu/School.aspx?schoolid=15016...
# 4       610225  http://iirc.niu.edu/School.aspx?schoolid=15016...
# ..         ...                                                ...
# 645     610563  http://iirc.niu.edu/School.aspx?schoolid=15016...
# 646     610570  http://iirc.niu.edu/School.aspx?schoolid=15016...
# 647     609764  http://iirc.niu.edu/School.aspx?schoolid=15016...
# 648     610106  http://iirc.niu.edu/School.aspx?schoolid=15016...
# 649     609726  http://iirc.niu.edu/School.aspx?schoolid=15016...
#
#      Mobility_Rate_Pct  Chronic_Truancy_Pct  Other_Metrics_Year_1  \
# 0                  8.0                 46.7                  2021
# 1                 17.1                 66.6                  2021
# 2                 11.1                 43.5                  2021
# 3                 12.2                 44.6                  2021
# 4                 13.4                 54.5                  2021
# ..                 ...                  ...                   ...
# 645                3.8                 51.0                  2021
# 646                NaN                  NaN                  2021
# 647                4.4                 66.4                  2021
# 648               13.3                 53.3                  2021
# 649                3.1                 49.7                  2021
#
#      Other_Metrics_Year_2
# 0                    2022
# 1                    2022
# 2                    2022
# 3                    2022
# 4                    2022
# ..                    ...
# 645                  2022
# 646                  2022
# 647                  2022
# 648                  2022
# 649                  2022
#
# [650 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 650 entries, 0 to 649
# Columns: 184 entries, School_ID to longitude
# dtypes: float64(147), int64(3), object(34)
# memory usage: 934.5+ KB

# %%
object_columns = df.select_dtypes(include=['object']).columns.tolist()

print(object_columns)
# Out:
# ['Short_Name', 'Long_Name', 'School_Type', 'Primary_Category', 'Address', 'City', 'State', 'Phone', 'Fax', 'CPS_School_Profile', 'Website', 'Student_Growth_Rating', 'Student_Growth_Description', 'Student_Attainment_Rating', 'Student_Attainment_Description', 'Culture_Climate_Rating', 'Culture_Climate_Description', 'Healthy_School_Certification', 'Healthy_School_Certification_Description', 'Creative_School_Certification', 'Creative_School_Certification_Description', 'School_Survey_Involved_Families', 'School_Survey_Supportive_Environment', 'School_Survey_Ambitious_Instruction', 'School_Survey_Effective_Leaders', 'School_Survey_Collaborative_Teachers', 'School_Survey_Safety', 'Average_Length_Suspension_Year_1_Pct', 'Average_Length_Suspension_Year_2_Pct', 'Average_Length_Suspension_Avg_Pct', 'State_School_Report_Card_URL', 'Empty_Progress_Report_Message', 'Supportive_School_Award', 'Supportive_School_Award_Desc']
